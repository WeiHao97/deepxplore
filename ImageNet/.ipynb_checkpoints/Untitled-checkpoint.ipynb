# %%
import numpy as np
import os
import PIL
import tensorflow as tf
import random
from tensorflow.python.framework.ops import disable_eager_execution
from tensorflow.python.framework.ops import enable_eager_execution
import cv2

#disable_eager_execution()
enable_eager_execution()

# %%
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import mixed_precision

# %%
from __future__ import print_function
import argparse
from tensorflow.keras.layers import Input
import scipy.misc

from configs import bcolors
from utils import *
import tensorflow_model_optimization as tfmot


from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg19 import VGG19

# %%
import tensorflow_datasets as tfds
from tiny_imagenet import TinyImagenetDataset

tiny_imagenet_builder = TinyImagenetDataset()

# this call (download_and_prepare) will trigger the download of the dataset
# and preparation (conversion to tfrecords)
#
# This will be done only once and on next usage tfds will
# use the cached version on your host.
#
# You can pass optional argument to this method called
# DownloadConfig (https://www.tensorflow.org/datasets/api_docs/python/tfds/download/DownloadConfig)
# to customize the location where the dataset is downloaded, extracted and processed.
tiny_imagenet_builder.download_and_prepare()

train_dataset = tiny_imagenet_builder.as_dataset(split="train")
validation_dataset = tiny_imagenet_builder.as_dataset(split="validation")

assert(isinstance(train_dataset, tf.data.Dataset))
assert(isinstance(validation_dataset, tf.data.Dataset))

# print info about the data
#print(tiny_imagenet_builder.info)

# %%
print(tiny_imagenet_builder.info)
# Out:
# tfds.core.DatasetInfo(
#     name='tiny_imagenet_dataset',
#     full_name='tiny_imagenet_dataset/0.1.0',
#     description="""
#     Tiny ImageNet Challenge is a similar challenge as ImageNet with a smaller dataset but
#                              less image classes. It contains 200 image classes, a training
#                              dataset of 100, 000 images, a validation dataset of 10, 000
#                              images, and a test dataset of 10, 000 images. All images are
#                              of size 64×64.
#     """,
#     homepage='https://www.tensorflow.org/datasets/catalog/tiny_imagenet_dataset',
#     data_path='/home/wei.hao/tensorflow_datasets/tiny_imagenet_dataset/0.1.0',
#     download_size=236.61 MiB,
#     dataset_size=210.18 MiB,
#     features=FeaturesDict({
#         'id': Text(shape=(), dtype=tf.string),
#         'image': Image(shape=(64, 64, 3), dtype=tf.uint8),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=200),
#     }),
#     supervised_keys=('image', 'label'),
#     splits={
#         'train': <SplitInfo num_examples=100000, num_shards=2>,
#         'validation': <SplitInfo num_examples=10000, num_shards=1>,
#     },
#     citation="""@article{tiny-imagenet,
#                                   author = {Li,Fei-Fei}, {Karpathy,Andrej} and {Johnson,Justin}"}""",
# )

# %%
train_images = []
train_labels = []
ds_numpy = tfds.as_numpy(train_dataset)
for item in ds_numpy:
    image, label, id = item["image"], item["label"], item["id"]
    train_images.append(keras.applications.vgg16.preprocess_input(cv2.resize(image, (224,224), interpolation = cv2.INTER_AREA)))
    train_labels.append(label)
    break
    
train_images = np.array(train_images)
train_labels = np.array(train_labels)

# %%
np.max(train_labels)

# %%
test_images = []
test_labels = []
ds_numpy = tfds.as_numpy(validation_dataset)
for item in ds_numpy:
    image, label, id = item["image"], item["label"], item["id"]
    test_images.append(np.expand_dims(keras.applications.vgg16.preprocess_input(image),axis=0))
    test_labels.append(label)
test_images = np.array(test_images)
test_labels = np.array(test_labels)

# %%
train_labels  = tf.keras.utils.to_categorical(train_labels , num_classes=200)
train_labels  = tf.keras.utils.to_categorical(train_labels , num_classes=200)

# %% [markdown]
# # Build Models

# %%
# input image dimensions
img_rows, img_cols = 224 ,224
input_shape = (img_rows, img_cols, 3)

K.clear_session()
# define input tensor as a placeholder
input_tensor_1 = Input(shape=[img_rows, img_cols, 3],dtype=tf.float32 )
input_tensor_2 = Input(shape=[img_rows, img_cols, 3])

# load multiple models sharing same input tensor
K.set_learning_phase(0)
model1 = VGG16(input_tensor=input_tensor_1)
model2 = VGG16(input_tensor=input_tensor_2)

quantize_model = tfmot.quantization.keras.quantize_model

# q_aware stands for for quantization aware.
model2 = quantize_model(model2)
# Out:
# WARNING:tensorflow:From <ipython-input-4-b5cb2fdcd59f>:11: set_learning_phase (from tensorflow.python.keras.backend) is deprecated and will be removed after 2020-10-11.
# Instructions for updating:
# Simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.

# %% [raw]
# # load multiple models sharing same input tensor
# K.set_learning_phase(0)
# resnet_v2_101 = tf.keras.Sequential([
#   keras.layers.InputLayer(input_shape=(224, 224, 3)),
#   hub.KerasLayer("https://tfhub.dev/google/imagenet/resnet_v2_101/classification/4")
# ])
#
# converter = tf.lite.TFLiteConverter.from_keras_model(resnet_v2_101)

# %% [markdown]
# # Load All Images (1000)

# %%
import re
def list_pictures(directory, ext='jpg|jpeg|bmp|png|ppm'):
    return [os.path.join(root, f)
            for root, _, files in os.walk(directory) for f in files
            if re.match(r'([\w]+\.(?:' + ext + '))', f)]

# %%
img_paths = list_pictures('./seeds/', ext='JPEG')
target_images = []
for img_path in img_paths:
    gen_img = preprocess_image(img_path)
    orig_img = gen_img.copy()
    # first check if input already induces differences
    pred1, pred2 = model1.predict(gen_img), model2.predict(gen_img)
    label1, label2 = np.argmax(pred1[0]), np.argmax(pred2[0])
    if label1 == label2:
        target_images.append(orig_img)

# %%
len(target_images)

# %%
with open('./test_images.npy', 'wb') as f:
    np.save(f, target_images[0])
    np.save(f, target_images[1])
    np.save(f, target_images[2])
    np.save(f, target_images[3])

# %% [markdown]
# # Load Images with Same Label (4?)

# %%
with open('ImageNetLabels.txt') as f:
    classes = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
classes = [x.strip() for x in classes]

# %%
target_images = []
with open('test_images.npy', 'rb') as f:
    target_images.append(np.load(f, encoding='bytes',allow_pickle=True))
    target_images.append(np.load(f, encoding='bytes',allow_pickle=True))
    target_images.append(np.load(f, encoding='bytes',allow_pickle=True))
    target_images.append(np.load(f, encoding='bytes',allow_pickle=True))

# %%
len(target_images)
# Out:
# 4

# %% [markdown]
# # Display Images

# %%
gen_img = target_images[1]
pil_img = tf.keras.preprocessing.image.array_to_img(gen_img[0,:,:,:])

# %%
from IPython.display import Image
display(pil_img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FE3E0C4C730>

# %%
pred1, pred2 = model1.predict(gen_img), model2.predict(gen_img)
label1, label2 = np.argmax(pred1[0]), np.argmax(pred2[0])
# Out:
# WARNING:tensorflow:From /home/wei.hao/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training_v1.py:2070: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.

# %%
tf.keras.applications.resnet.decode_predictions(pred1, top=5)[0]
# Out:
# [('n03992509', "potter's_wheel", 0.5384481),
#  ('n04259630', 'sombrero', 0.18596433),
#  ('n03786901', 'mortar', 0.042235207),
#  ('n03970156', 'plunger', 0.029749354),
#  ('n04447861', 'toilet_seat', 0.022260444)]

# %%
tf.keras.applications.resnet.decode_predictions(pred2, top=5)[0]
# Out:
# [('n03992509', "potter's_wheel", 0.003064962),
#  ('n02791270', 'barbershop', 0.0022047707),
#  ('n03929855', 'pickelhaube', 0.0020067284),
#  ('n07754684', 'jackfruit', 0.0019144817),
#  ('n02098286', 'West_Highland_white_terrier', 0.0019144817)]

# %%
model1.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# quantize_layer (QuantizeLaye (None, 224, 224, 3)       3
# _________________________________________________________________
# quant_block1_conv1 (Quantize (None, 224, 224, 64)      1923
# _________________________________________________________________
# quant_block1_conv2 (Quantize (None, 224, 224, 64)      37059
# _________________________________________________________________
# quant_block1_pool (QuantizeW (None, 112, 112, 64)      1
# _________________________________________________________________
# quant_block2_conv1 (Quantize (None, 112, 112, 128)     74115
# _________________________________________________________________
# quant_block2_conv2 (Quantize (None, 112, 112, 128)     147843
# _________________________________________________________________
# quant_block2_pool (QuantizeW (None, 56, 56, 128)       1
# _________________________________________________________________
# quant_block3_conv1 (Quantize (None, 56, 56, 256)       295683
# _________________________________________________________________
# quant_block3_conv2 (Quantize (None, 56, 56, 256)       590595
# _________________________________________________________________
# quant_block3_conv3 (Quantize (None, 56, 56, 256)       590595
# _________________________________________________________________
# quant_block3_pool (QuantizeW (None, 28, 28, 256)       1
# _________________________________________________________________
# quant_block4_conv1 (Quantize (None, 28, 28, 512)       1181187
# _________________________________________________________________
# quant_block4_conv2 (Quantize (None, 28, 28, 512)       2360835
# _________________________________________________________________
# quant_block4_conv3 (Quantize (None, 28, 28, 512)       2360835
# _________________________________________________________________
# quant_block4_pool (QuantizeW (None, 14, 14, 512)       1
# _________________________________________________________________
# quant_block5_conv1 (Quantize (None, 14, 14, 512)       2360835
# _________________________________________________________________
# quant_block5_conv2 (Quantize (None, 14, 14, 512)       2360835
# _________________________________________________________________
# quant_block5_conv3 (Quantize (None, 14, 14, 512)       2360835
# _________________________________________________________________
# quant_block5_pool (QuantizeW (None, 7, 7, 512)         1
# _________________________________________________________________
# quant_flatten (QuantizeWrapp (None, 25088)             1
# _________________________________________________________________
# quant_fc1 (QuantizeWrapper)  (None, 4096)              102764549
# _________________________________________________________________
# quant_fc2 (QuantizeWrapper)  (None, 4096)              16781317
# _________________________________________________________________
# quant_predictions (QuantizeW (None, 1000)              4097005
# =================================================================
# Total params: 138,366,055
# Trainable params: 138,357,544
# Non-trainable params: 8,511
# _________________________________________________________________

# %% [markdown]
# # Generate

# %%
weight_diff = 1
orig_label = label1

# %%
quantized_input = model2.get_layer('input_2').input
loss2 = K.mean(model2.get_layer('quant_predictions').output[..., orig_label])
grads =tf.gradients(loss2, quantized_input)[0]
iterate = K.function([input_tensor_2], [grads])

# %%
grads
# Out:
# <tf.Tensor 'gradients_5/quantize_layer_1/AllValuesQuantize/FakeQuantWithMinMaxVars_grad/FakeQuantWithMinMaxVarsGradient:0' shape=(None, 224, 224, 3) dtype=float32>

# %%
input_ = model1.get_layer('input_1').input
loss1 = K.mean(model1.get_layer('predictions').output[..., orig_label])
grads = tf.gradients(loss1, input_tensor_1)[0]
iterate = K.function([input_tensor_1], [grads])

# %%
grads
# Out:
# <tf.Tensor 'gradients_1/block1_conv1/Conv2D_grad/Conv2DBackpropInput:0' shape=(None, 224, 224, 3) dtype=float32>

# %%
grads_value = iterate(gen_img)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-31-cd03a7b46bb1> in <module>
# ----> 1 grads_value = iterate(gen_img)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3822       self._make_callable(feed_arrays, feed_symbols, symbol_vals, session)
#    3823
# -> 3824     fetched = self._callable_fn(*array_vals,
#    3825                                 run_metadata=self.run_metadata)
#    3826     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1468       try:
#    1469         run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
# -> 1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
#    1472                                                run_metadata_ptr)
#
# InvalidArgumentError: 2 root error(s) found.
#   (0) Invalid argument: You must feed a value for placeholder tensor 'input_2_5' with dtype float and shape [?,224,224,3]
# 	 [[{{node input_2_5}}]]
# 	 [[gradients_5/quantize_layer_1/AllValuesQuantize/FakeQuantWithMinMaxVars_grad/FakeQuantWithMinMaxVarsGradient/_1583]]
#   (1) Invalid argument: You must feed a value for placeholder tensor 'input_2_5' with dtype float and shape [?,224,224,3]
# 	 [[{{node input_2_5}}]]
# 0 successful operations.
# 0 derived errors ignored.

# %%
input_ = model1.get_layer('input_1').input
loss1 = K.mean(model1.get_layer('predictions').output[..., orig_label])
grads = tf.gradients(loss1, input_)[0]
iterate = K.function([input_tensor_1], [grads])

# %%
grads
# Out:
# <tf.Tensor 'gradients_2/block1_conv1/Conv2D_grad/Conv2DBackpropInput:0' shape=(None, 224, 224, 3) dtype=float32>

# %%
grads_value = iterate(gen_img.astype(int))

# %%
loss1 = K.mean(model1.get_layer('predictions').output[..., orig_label])
loss2 = K.mean(model2.get_layer('quant_predictions').output[..., orig_label])
quantized_input = model2.get_layer('quant_block1_conv1').input

# we compute the gradient of the input picture wrt this loss
grads = normalize(tf.gradients(loss1, input_tensor)[0] - tf.gradients(loss2, quantized_input)[0])

# this function returns the loss and grads given the input picture
iterate = K.function([input_tensor], [grads])

# %%
transformation = 'light'
start_point = (0, 0)
occlusion_size =(50, 50)
step = 10
grad_iterations = 100000

# %%
orig_img = gen_img.copy()

# %%
model2.get_layer('quantize_layer').output
# Out:
# <tf.Tensor 'quantize_layer/AllValuesQuantize/FakeQuantWithMinMaxVars:0' shape=(None, 224, 224, 3) dtype=float32>

# %%
model2.get_layer('input_1').output
# Out:
# <tf.Tensor 'input_1_5:0' shape=(None, 224, 224, 3) dtype=float32>

# %%
model1.get_layer('input_1').output
# Out:
# <tf.Tensor 'input_1:0' shape=(None, 224, 224, 3) dtype=float32>

# %%
# this function returns the loss and grads given the input picture
layer1 = tf.quantization.fake_quant_with_min_max_vars(
    input_tensor, -123.68000030517578,151.06100463867188, num_bits=8
)
lll = K.function([input_tensor], [layer1])

# %%
layer1
# Out:
# <tf.Tensor 'FakeQuantWithMinMaxVars_2:0' shape=(None, 224, 224, 3) dtype=float32>

# %%
# we run gradient ascent for 20 steps
for iters in range(0,grad_iterations):
    
    loss_value1, grads_value = iterate(gen_img.astype(float))
    if transformation == 'light':
        grads_value = constraint_light(grads_value)  # constraint the gradients value
    elif transformation == 'occl':
        grads_value = constraint_occl(grads_value, start_point,occlusion_size)  # constraint the gradients value
    elif transformation == 'blackout':
        grads_value = constraint_black(grads_value)  # constraint the gradients value

    gen_img += grads_value * step
    pred1, pred2= model1.predict(gen_img), model2.predict(gen_img)
    label1, label2 = np.argmax(pred1[0]), np.argmax(pred2[0])
    if not label1 == label2:
        gen_img_deprocessed = deprocess_image(gen_img)
        orig_img_deprocessed = deprocess_image(orig_img)
        print("yeah")
        break
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-40-b2403c514d94> in <module>
#       2 for iters in range(0,grad_iterations):
#       3
# ----> 4     loss_value1, grads_value = iterate(gen_img.astype(float))
#       5     if transformation == 'light':
#       6         grads_value = constraint_light(grads_value)  # constraint the gradients value
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3822       self._make_callable(feed_arrays, feed_symbols, symbol_vals, session)
#    3823
# -> 3824     fetched = self._callable_fn(*array_vals,
#    3825                                 run_metadata=self.run_metadata)
#    3826     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1468       try:
#    1469         run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
# -> 1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
#    1472                                                run_metadata_ptr)
#
# InvalidArgumentError: 2 root error(s) found.
#   (0) Invalid argument: You must feed a value for placeholder tensor 'input_1_5' with dtype float and shape [?,224,224,3]
# 	 [[{{node input_1_5}}]]
# 	 [[truediv_2/_1275]]
#   (1) Invalid argument: You must feed a value for placeholder tensor 'input_1_5' with dtype float and shape [?,224,224,3]
# 	 [[{{node input_1_5}}]]
# 0 successful operations.
# 0 derived errors ignored.

# %%
orig_img - gen_img
