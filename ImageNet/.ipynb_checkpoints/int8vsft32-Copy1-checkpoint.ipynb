# %%
import numpy as np
import os

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="3"

# %%
import PIL
import tensorflow as tf
import random
from tensorflow.python.framework.ops import disable_eager_execution
from tensorflow.python.framework.ops import enable_eager_execution
#disable_eager_execution()
enable_eager_execution()

# %%
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications.resnet50 import ResNet50
import tensorflow_datasets as tfds

# %%
from __future__ import print_function
import argparse
from tensorflow.keras.layers import Input
import scipy.misc

from configs import bcolors
from utils import *
import tensorflow_model_optimization as tfmot

# %%
def preprocess_image(features):
    """Preprocesses the given image.

      Args:
        image: `Tensor` representing an image of arbitrary size.

      Returns:
        A preprocessed image `Tensor` of range [0, 1].
  """
    image = features["image"]
    image = tf.image.resize(image,[224,224])
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    image = tf.keras.applications.resnet.preprocess_input(image)
    #image = center_crop(image, 224, 224, crop_proportion=0.875)   # Standard for ImageNet.
    #image = tf.reshape(image, [224, 224, 3])
    #image = tf.clip_by_value(image, 0., 1.)
    
    features["image"] = image
    return features

# %% [markdown]
# # Load Data

# %%
BATCH_SIZE = 50
tfds_dataset2, tfds_info  = tfds.load(name='imagenet2012_subset', split='validation[-20%:]', with_info=True,
                                     data_dir='/local/rcs/wei/image_net/')
#tf.compat.v1.data.make_one_shot_iterator(tfds_dataset1).get_next()

# %%
figs = tfds.show_examples(tfds_dataset2, tfds_info)

# %%
val_ds = tfds_dataset2.map(preprocess_image).batch(BATCH_SIZE).prefetch(1)

# %% [markdown]
# # Load Model

# %%
# input image dimensions
img_rows, img_cols = 224 ,224
input_shape = (img_rows, img_cols, 3)
model_ = ResNet50(input_shape=input_shape)

# %%
q_model = tfmot.quantization.keras.quantize_model(model_)

# %%
model = ResNet50(input_tensor = q_model.get_layer('input_1').input)

# %%
model.load_weights("./original_model.h5")
q_model.load_weights("./q_model.h5")

# %% [markdown]
# # Display Image

# %%
def extract():
    for i, features in enumerate(val_ds):
        image = np.expand_dims(features["image"].numpy()[0], axis=0)
        label = features["label"].numpy()[0]
        logits_1 = model(image).numpy()
        logits_2 = q_model(image).numpy()
        predict_1 = tf.argmax(logits_1, axis=-1).numpy()
        predict_2 = tf.argmax(logits_2, axis=-1).numpy()
        break
    return image,label,logits_1,logits_2,predict_1,predict_2

# %%
image,label,logits_1,logits_2,predict_1,predict_2 = extract()

# %%
pil_img = tf.keras.preprocessing.image.array_to_img(image[0,:,:,:])
from IPython.display import Image
display(pil_img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F854C641F10>

# %%
tf.keras.applications.resnet.decode_predictions(logits_1, top=5)[0]
# Out:
# [('n04467665', 'trailer_truck', 0.9033519),
#  ('n03393912', 'freight_car', 0.048705902),
#  ('n03417042', 'garbage_truck', 0.017315276),
#  ('n03776460', 'mobile_home', 0.014964416),
#  ('n03796401', 'moving_van', 0.010416642)]

# %%
tf.keras.applications.resnet.decode_predictions(logits_2, top=5)[0]
# Out:
# [('n04467665', 'trailer_truck', 0.68862236),
#  ('n03417042', 'garbage_truck', 0.16085596),
#  ('n03393912', 'freight_car', 0.07406508),
#  ('n03796401', 'moving_van', 0.041399576),
#  ('n03776460', 'mobile_home', 0.011739717)]

# %%
label
# Out:
# 867

# %%
np.save("./trailer_truck.npy",image)

# %% [markdown]
# # Generate adverserial example

# %%
image = np.load("./trailer_truck.npy")

# %%
weight_diff = 10
orig_label = 867
grad_iterations = 20
transformation = 'light'
step = 10

# %%
input_tensor = q_model.inputs
loss1 =  K.mean(model.get_layer('predictions').output[..., orig_label])
loss2 =  K.mean(q_model.get_layer('quant_predictions').output[..., orig_label])

# %%
# K = tensorflow.keras.backend
input_image = tf.convert_to_tensor(image)

with tf.GradientTape() as g:
    g.watch(input_image)
    loss1 = K.mean(model(input_image)[..., orig_label])
    loss2 = K.mean(q_model(input_image)[..., orig_label])
    final_loss = K.mean(loss1 - weight_diff*loss2)
print(final_loss)
model.load_weights("./original_model.h5")
q_model.load_weights("./q_model.h5")
grads = normalize(g.gradient(final_loss, input_image)[0])
# iterate = K.function([input_tensor], [grads])

#grads = tf.gradients(loss1, input_tensor_1)[0] - weight_diff*tf.gradients(loss2, input_tensor_2)[0]
#iterate = K.function([input_tensor_1,input_tensor_2], [grads])
# Out:
# tf.Tensor(-5.982872, shape=(), dtype=float32)

# %%
print(grads)
# Out:
# tf.Tensor(
# [[[-2.74960428e-01 -1.81307830e-02  7.09611326e-02]
#   [ 1.08972222e-01  2.47135967e-01  2.07452670e-01]
#   [ 1.55081540e-01  1.56718463e-01  5.88117205e-02]
#   ...
#   [-8.10210928e-02 -8.66750181e-02 -1.14962654e-02]
#   [-1.79618038e-02 -1.03781804e-01 -7.79191926e-02]
#   [ 1.43638581e-01  2.17719823e-01  1.20512672e-01]]
#
#  [[ 3.58977206e-02  2.96348929e-01  3.89064848e-01]
#   [-4.94360365e-02 -2.09070399e-01  4.57301438e-02]
#   [-3.69674504e-01 -5.82015812e-01 -3.44108075e-01]
#   ...
#   [-8.12337734e-03 -8.29098932e-03  2.90040136e-03]
#   [-8.52958336e-02 -1.55423135e-01 -9.77731571e-02]
#   [ 1.77237242e-02  8.46454315e-03 -1.44972065e-02]]
#
#  [[-2.68557459e-01 -3.44761908e-01 -1.90433100e-01]
#   [-8.67059886e-01 -1.49460924e+00 -9.84256923e-01]
#   [-8.74543846e-01 -1.27312064e+00 -8.43211770e-01]
#   ...
#   [ 1.15224689e-01  2.39819944e-01  1.62300691e-01]
#   [ 5.30105643e-02  1.68121994e-01  1.34113878e-01]
#   [-2.62974426e-02  2.41249837e-02  1.45221148e-02]]
#
#  ...
#
#  [[ 9.46656521e-03  1.22391522e-01  9.74636003e-02]
#   [-5.11014909e-02 -5.63939176e-02 -7.87357017e-02]
#   [ 2.19878688e-01  2.61897981e-01  1.70607507e-01]
#   ...
#   [-2.08148025e-02  1.19535677e-01  9.81964078e-03]
#   [-3.24174063e-04  4.08385135e-02 -2.98650861e-02]
#   [ 2.79515944e-02  7.01543838e-02 -9.17100720e-03]]
#
#  [[ 4.45420183e-02  5.19545823e-02  1.05158783e-01]
#   [-3.40798572e-02 -1.32886469e-01 -3.53037305e-02]
#   [ 4.73765731e-02  5.89927938e-03  2.50998084e-02]
#   ...
#   [-3.85002941e-02  2.19654813e-02 -2.39058193e-02]
#   [ 1.27718048e-02  3.79945934e-02  3.74548547e-02]
#   [ 2.83556711e-02  4.40425351e-02  4.04644422e-02]]
#
#  [[ 7.39185587e-02  1.58000305e-01  2.03933537e-01]
#   [ 2.93752532e-02  2.42504850e-02  1.47658095e-01]
#   [ 7.48206228e-02  6.28036335e-02  1.25124902e-01]
#   ...
#   [-3.66669148e-02  1.86040960e-02 -1.25040468e-02]
#   [ 2.31259931e-02  3.66863273e-02  4.20226008e-02]
#   [-2.47183256e-03 -1.91739481e-02 -5.24133677e-03]]], shape=(224, 224, 3), dtype=float32)

# %%
orig_img = image.copy()
for iters in range(0,grad_iterations):
    grads_value = grads #iterate([image])[0]
    if transformation == 'light':
        grads_value = constraint_light(grads_value)  # constraint the gradients value
    elif transformation == 'occl':
        grads_value = constraint_occl(grads_value, start_point,occlusion_size)  # constraint the gradients value
    elif transformation == 'blackout':
        grads_value = constraint_black(grads_value)  # constraint the gradients value

    image += grads_value * step    
    pred1, pred2= model.predict(image), q_model.predict(image)
    label1, label2 = np.argmax(pred1[0]), np.argmax(pred2[0])
    if not label1 == label2:
        print("different")
        print(label1)
        print(label2)
        print(tf.keras.applications.resnet.decode_predictions(pred1, top=5)[0])
        print(tf.keras.applications.resnet.decode_predictions(pred2, top=5)[0])
        gen_img_deprocessed = deprocess_image(image)
        orig_img_deprocessed = deprocess_image(orig_img)
        break
# Out:
# different
# 565
# 867
# [('n03393912', 'freight_car', 0.4785751), ('n04467665', 'trailer_truck', 0.45678234), ('n03417042', 'garbage_truck', 0.01779615), ('n04310018', 'steam_locomotive', 0.0146016665), ('n03796401', 'moving_van', 0.01324699)]
# [('n04467665', 'trailer_truck', 0.5862611), ('n03393912', 'freight_car', 0.24499929), ('n03417042', 'garbage_truck', 0.08433972), ('n03796401', 'moving_van', 0.03524566), ('n04310018', 'steam_locomotive', 0.016228642)]

# %%
tf.keras.applications.resnet.decode_predictions(pred1, top=5)[0]
# Out:
# [('n03393912', 'freight_car', 0.4785751),
#  ('n04467665', 'trailer_truck', 0.45678234),
#  ('n03417042', 'garbage_truck', 0.01779615),
#  ('n04310018', 'steam_locomotive', 0.0146016665),
#  ('n03796401', 'moving_van', 0.01324699)]

# %%
tf.keras.applications.resnet.decode_predictions(pred2, top=5)[0]
# Out:
# [('n04467665', 'trailer_truck', 0.5862611),
#  ('n03393912', 'freight_car', 0.24499929),
#  ('n03417042', 'garbage_truck', 0.08433972),
#  ('n03796401', 'moving_van', 0.03524566),
#  ('n04310018', 'steam_locomotive', 0.016228642)]

# %%
tf.keras.preprocessing.image.array_to_img(gen_image[0,:,:,:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-da981071bb57> in <module>
# ----> 1 tf.keras.preprocessing.image.array_to_img(gen_image[0,:,:,:])
#
# NameError: name 'gen_image' is not defined

# %%
tf.keras.preprocessing.image.array_to_img(gen_img_deprocessed)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F854C6669D0>

# %%
tf.keras.preprocessing.image.array_to_img(orig_img_deprocessed)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F897D782910>
